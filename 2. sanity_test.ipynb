# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/pl_metric_learning_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/pl_metric_learning_defect

# %%
# !pip install -q timm wandb torchmetrics pytorch-lightning &> /dev/null
# !pip install -q hydra-core --upgrade &> /dev/null

# %%
# !ls
# Out:
# '1. train.ipynb'	 config         model	    sanity_test.py   train.py
# '2. sanity_test.ipynb'	 inference.py   notebooks   src
# '3. inference.ipynb'	 input	        output	    submit

# %%
# !python sanity_test.py
# Out:
# Sanity Checking: 0it [00:00, ?it/s]/usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryAccuracy', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryPrecision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryRecall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinarySpecificity', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryF1Score', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryFBetaScore', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0:   0% 0/63 [00:00<?, ?it/s] /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryAccuracy', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryPrecision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryRecall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinarySpecificity', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryF1Score', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryFBetaScore', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# Epoch 0:  79% 50/63 [00:18<00:04,  2.67it/s, loss=0.743]
# Validation: 0it [00:00, ?it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fef02339b80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1466, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1449, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fef02339b80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1466, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1449, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#
# Validation:   0% 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/13 [00:00<?, ?it/s]
# Epoch 0:  81% 51/63 [00:19<00:04,  2.67it/s, loss=0.743]
# Epoch 0:  83% 52/63 [00:19<00:04,  2.72it/s, loss=0.743]
# Epoch 0:  84% 53/63 [00:19<00:03,  2.76it/s, loss=0.743]
# Epoch 0:  86% 54/63 [00:19<00:03,  2.80it/s, loss=0.743]
# Epoch 0:  87% 55/63 [00:19<00:02,  2.85it/s, loss=0.743]
# Epoch 0:  89% 56/63 [00:19<00:02,  2.89it/s, loss=0.743]
# Epoch 0:  90% 57/63 [00:19<00:02,  2.93it/s, loss=0.743]
# Epoch 0:  92% 58/63 [00:19<00:01,  2.97it/s, loss=0.743]
# Epoch 0:  94% 59/63 [00:19<00:01,  3.01it/s, loss=0.743]
# Epoch 0:  95% 60/63 [00:19<00:00,  3.06it/s, loss=0.743]
# Epoch 0:  97% 61/63 [00:19<00:00,  3.10it/s, loss=0.743]
# Epoch 0:  98% 62/63 [00:19<00:00,  3.14it/s, loss=0.743]
# Epoch 0: 100% 63/63 [00:19<00:00,  3.18it/s, loss=0.743, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692]
# Epoch 1:  79% 50/63 [00:20<00:05,  2.49it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/13 [00:00<?, ?it/s]
# Epoch 1:  81% 51/63 [00:20<00:04,  2.51it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  83% 52/63 [00:20<00:04,  2.55it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  84% 53/63 [00:20<00:03,  2.59it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  86% 54/63 [00:20<00:03,  2.63it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  87% 55/63 [00:20<00:02,  2.68it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  89% 56/63 [00:20<00:02,  2.72it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  90% 57/63 [00:20<00:02,  2.76it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  92% 58/63 [00:20<00:01,  2.80it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  94% 59/63 [00:20<00:01,  2.84it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  95% 60/63 [00:20<00:01,  2.88it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  97% 61/63 [00:20<00:00,  2.92it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1:  98% 62/63 [00:20<00:00,  2.96it/s, loss=0.435, val_loss=0.602, val_BinaryAccuracy=0.680, val_BinaryPrecision=0.562, val_BinaryRecall=0.900, val_BinarySpecificity=0.533, val_BinaryF1Score=0.692, val_BinaryFBetaScore=0.692, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1: 100% 63/63 [00:21<00:00,  3.00it/s, loss=0.435, val_loss=0.483, val_BinaryAccuracy=0.720, val_BinaryPrecision=1.000, val_BinaryRecall=0.300, val_BinarySpecificity=1.000, val_BinaryF1Score=0.462, val_BinaryFBetaScore=0.462, train_loss=1.640, train_BinaryAccuracy=0.560, train_BinaryPrecision=0.446, train_BinaryRecall=0.412, train_BinarySpecificity=0.658, train_BinaryF1Score=0.429, train_BinaryFBetaScore=0.429]
# Epoch 1: 100% 63/63 [00:25<00:00,  2.49it/s, loss=0.435, val_loss=0.483, val_BinaryAccuracy=0.720, val_BinaryPrecision=1.000, val_BinaryRecall=0.300, val_BinarySpecificity=1.000, val_BinaryF1Score=0.462, val_BinaryFBetaScore=0.462, train_loss=0.475, train_BinaryAccuracy=0.745, train_BinaryPrecision=0.679, train_BinaryRecall=0.688, train_BinarySpecificity=0.783, train_BinaryF1Score=0.683, train_BinaryFBetaScore=0.683]
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing DataLoader 0: 100% 50/50 [00:01<00:00, 36.11it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       test_accuracy                0.72
#         test_auc            0.9783333333333333
#        test_fbeta           0.6361746361746362
#        test_kappa            0.339622641509434
#      test_precision         0.8409090909090908
#        test_recall                 0.65
#      test_specifity                 1.0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
