# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/pl_metric_learning_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/pl_metric_learning_defect

# %%
# !pip install -q timm wandb torchmetrics==0.11.1 pytorch-lightning==1.9.0 &> /dev/null
# !pip install -q hydra-core --upgrade &> /dev/null

# %%
# !ls
# Out:
# '1. train.ipynb'	 config         model	    sanity_test.py   train.py
# '2. sanity_test.ipynb'	 inference.py   notebooks   src
# '3. inference.ipynb'	 input	        output	    submit

# %%
# !python sanity_test.py
# Out:
# Downloading model.safetensors: 100% 354M/354M [00:00<00:00, 370MB/s]
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryAccuracy', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryPrecision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryRecall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinarySpecificity', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryF1Score', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryFBetaScore', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# Epoch 0:   0% 0/63 [00:00<?, ?it/s] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryAccuracy', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryPrecision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryRecall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinarySpecificity', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryF1Score', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryFBetaScore', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# Epoch 0:  63% 40/63 [00:47<00:27,  1.18s/it, loss=0.741]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/13 [00:00<?, ?it/s]
# Epoch 0:  95% 60/63 [01:03<00:03,  1.06s/it, loss=0.741]
# Epoch 0: 100% 63/63 [01:07<00:00,  1.07s/it, loss=0.72, val_loss=2.370, val_BinaryAccuracy=0.420, val_BinaryPrecision=0.408, val_BinaryRecall=1.000, val_BinarySpecificity=0.0333, val_BinaryF1Score=0.580, val_BinaryFBetaScore=0.580]
# Epoch 0: 100% 63/63 [01:12<00:00,  1.15s/it, loss=0.72, val_loss=2.370, val_BinaryAccuracy=0.420, val_BinaryPrecision=0.408, val_BinaryRecall=1.000, val_BinarySpecificity=0.0333, val_BinaryF1Score=0.580, val_BinaryFBetaScore=0.580, train_loss=1.370, train_BinaryAccuracy=0.575, train_BinaryPrecision=0.468, train_BinaryRecall=0.463, train_BinarySpecificity=0.650, train_BinaryF1Score=0.465, train_BinaryFBetaScore=0.465]
# Testing DataLoader 0: 100% 50/50 [00:04<00:00, 11.17it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test_accuracy       │           0.42            │
# │         test_auc          │            1.0            │
# │        test_fbeta         │    0.3221131369798972     │
# │        test_kappa         │    0.02684563758389258    │
# │      test_precision       │    0.7040816326530612     │
# │        test_recall        │    0.5166666666666667     │
# │      test_specifity       │    0.03333333507180214    │
# └───────────────────────────┴───────────────────────────┘
