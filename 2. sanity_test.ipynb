# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/pl_metric_learning_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/pl_metric_learning_defect

# %%
# !pip install -q timm wandb torchmetrics pytorch-lightning &> /dev/null
# !pip install -q hydra-core --upgrade &> /dev/null

# %%
# !ls
# Out:
# '1. train.ipynb'	 input	     output	      submit
# '2. sanity_test.ipynb'	 model	     sanity_test.py   train.py
#  config			 notebooks   src

# %%
# !python sanity_test.py
# Out:
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# Sanity Checking: 0it [00:00, ?it/s]/usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s]/usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryAccuracy', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryPrecision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryRecall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinarySpecificity', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryF1Score', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('val_BinaryFBetaScore', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0:   0% 0/63 [00:00<?, ?it/s] /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_loss', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryAccuracy', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryPrecision', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryRecall', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinarySpecificity', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryF1Score', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/core/module.py:483: UserWarning: You called `self.log('train_BinaryFBetaScore', ..., logger=True)` but have no logger configured. You can enable one by doing `Trainer(logger=ALogger(...))`
#   rank_zero_warn(
# Epoch 0:  79% 50/63 [00:17<00:04,  2.89it/s, loss=18.1]
# Validation: 0it [00:00, ?it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f0202ad5b80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1466, in __del__
#     self._shutdown_workers()
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f0202ad5b80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1466, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1449, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#   File "/usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py", line 1449, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#
# Validation:   0% 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/13 [00:00<?, ?it/s]
# Epoch 0:  81% 51/63 [00:17<00:04,  2.89it/s, loss=18.1]
# Epoch 0:  83% 52/63 [00:17<00:03,  2.94it/s, loss=18.1]
# Epoch 0:  84% 53/63 [00:17<00:03,  2.98it/s, loss=18.1]
# Epoch 0:  86% 54/63 [00:17<00:02,  3.03it/s, loss=18.1]
# Epoch 0:  87% 55/63 [00:17<00:02,  3.08it/s, loss=18.1]
# Epoch 0:  89% 56/63 [00:17<00:02,  3.12it/s, loss=18.1]
# Epoch 0:  90% 57/63 [00:17<00:01,  3.17it/s, loss=18.1]
# Epoch 0:  92% 58/63 [00:18<00:01,  3.21it/s, loss=18.1]
# Epoch 0:  94% 59/63 [00:18<00:01,  3.26it/s, loss=18.1]
# Epoch 0:  95% 60/63 [00:18<00:00,  3.31it/s, loss=18.1]
# Epoch 0:  97% 61/63 [00:18<00:00,  3.35it/s, loss=18.1]
# Epoch 0:  98% 62/63 [00:18<00:00,  3.39it/s, loss=18.1]
# Epoch 0: 100% 63/63 [00:18<00:00,  3.44it/s, loss=18.1, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000]
# Epoch 0: 100% 63/63 [00:18<00:00,  3.44it/s, loss=18.1, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]tcmalloc: large alloc 1196359680 bytes == 0x135f38000 @  0x7f0288616680 0x7f0288636da2 0x5f714c 0x64d800 0x527022 0x5c4520 0x5f6eb7 0x7f02666b0795 0x7f0266808eeb 0x7f023fbb9c45 0x7f023fbb3728 0x7f023fbbb2c9 0x7f026681c9ca 0x7f0266403f00 0x5f5b39 0x5f6706 0x50ba83 0x570b82 0x569d8a 0x5f60c3 0x56bab6 0x569d8a 0x5f60c3 0x570b82 0x5f5ee6 0x56bab6 0x569d8a 0x50b3a0 0x56cc92 0x569d8a 0x50b3a0
# Epoch 1:  79% 50/63 [00:18<00:04,  2.77it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/13 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/13 [00:00<?, ?it/s]
# Epoch 1:  81% 51/63 [00:18<00:04,  2.78it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  83% 52/63 [00:18<00:03,  2.83it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  84% 53/63 [00:18<00:03,  2.87it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  86% 54/63 [00:18<00:03,  2.92it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  87% 55/63 [00:18<00:02,  2.96it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  89% 56/63 [00:18<00:02,  3.01it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  90% 57/63 [00:18<00:01,  3.05it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  92% 58/63 [00:18<00:01,  3.10it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  94% 59/63 [00:18<00:01,  3.14it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  95% 60/63 [00:18<00:00,  3.18it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  97% 61/63 [00:18<00:00,  3.23it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1:  98% 62/63 [00:18<00:00,  3.27it/s, loss=11.3, val_loss=15.50, val_BinaryAccuracy=0.000, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.000, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1: 100% 63/63 [00:18<00:00,  3.32it/s, loss=11.3, val_loss=11.70, val_BinaryAccuracy=0.180, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.300, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=22.10, train_BinaryAccuracy=0.260, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.433, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# Epoch 1: 100% 63/63 [00:26<00:00,  2.38it/s, loss=11.3, val_loss=11.70, val_BinaryAccuracy=0.180, val_BinaryPrecision=0.000, val_BinaryRecall=0.000, val_BinarySpecificity=0.300, val_BinaryF1Score=0.000, val_BinaryFBetaScore=0.000, train_loss=13.70, train_BinaryAccuracy=0.145, train_BinaryPrecision=0.000, train_BinaryRecall=0.000, train_BinarySpecificity=0.242, train_BinaryF1Score=0.000, train_BinaryFBetaScore=0.000]
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 4 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing DataLoader 0: 100% 50/50 [00:01<00:00, 37.14it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#       test_accuracy                0.18
#         test_auc                    0.0
#        test_fbeta           0.15254237288135594
#        test_kappa           -0.694214876033058
#      test_precision         0.15517241379310345
#        test_recall                 0.15
#      test_specifity         0.30000001192092896
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
