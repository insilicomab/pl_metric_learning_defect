# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/pl_metric_learning_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/pl_metric_learning_defect

# %%
# !pip install -q timm wandb torchmetrics==0.11.1 pytorch-lightning==1.9.0 &> /dev/null
# !pip install faiss-cpu faiss-gpu &> /dev/null
# !pip install -q hydra-core --upgrade &> /dev/null

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python inference.py --timm_name convnext_base \
                     --layer_name ArcFace \
                     --model_name glamorous-surf-9 \
                     --wandb_run_path insilicomab/pl-metric-learning-defective/teuiq1me \
                     --image_size 224 \
                     --embedding_size 512 \
                     --k 10
# Out:
# 100% 100/100 [00:55<00:00,  1.81it/s]
